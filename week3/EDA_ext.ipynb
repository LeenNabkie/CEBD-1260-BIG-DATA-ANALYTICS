# %% [markdown]
# # Exploratory Data Analysis

# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt

# the more advanced python visualization library
import seaborn as sns

# apply style to all the charts
sns.set_style('whitegrid')

# convert scientific notation to decimals
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Load the data
df = pd.read_csv('data/house_pricing.csv')
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.00         3       1.00         1180
# 1      6414100192 2014-12-09  538000.00         3       2.25         2570
# 2      5631500400 2015-02-25  180000.00         2       1.00          770
# 3      2487200875 2014-12-09  604000.00         4       3.00         1960
# 4      1954400510 2015-02-18  510000.00         3       2.00         1680
# 5      7237550310 2014-05-12 1225000.00         4       4.50         5420
# 6      1321400060 2014-06-27  257500.00         3       2.25         1715
# 7      2008000270 2015-01-15  291850.00         3       1.50         1060
# 8      2414600126 2015-04-15  229500.00         3       1.00         1780
# 9      3793500160 2015-03-12  323000.00         3       2.50         1890
# 10     1736800520 2015-04-03  662500.00         3       2.50         3560
# 11     9212900260 2014-05-27  468000.00         2       1.00         1160
# 12      114101516 2014-05-28  310000.00         3       1.00         1430
# 13     6054650070 2014-10-07  400000.00         3       1.75         1370
# 14     1175000570 2015-03-12  530000.00         5       2.00         1810
# 15     9297300055 2015-01-24  650000.00         4       3.00         2950
# 16     1875500060 2014-07-31  395000.00         3       2.00         1890
# 17     6865200140 2014-05-29  485000.00         4       1.00         1600
# 18       16000397 2014-12-05  189000.00         2       1.00         1200
# 19     7983200060 2015-04-24  230000.00         3       1.00         1250
# 20     6300500875 2014-05-14  385000.00         4       1.75         1620
# 21     2524049179 2014-08-26 2000000.00         3       2.75         3050
# 22     7137970340 2014-07-03  285000.00         5       2.50         2270
# 23     8091400200 2014-05-16  252700.00         2       1.50         1070
# 24     3814700200 2014-11-20  329000.00         3       2.25         2450
# 25     1202000200 2014-11-03  233000.00         3       2.00         1710
# 26     1794500383 2014-06-26  937000.00         3       1.75         2450
# 27     3303700376 2014-12-01  667000.00         3       1.00         1400
# 28     5101402488 2014-06-24  438000.00         3       1.75         1520
# 29     1873100390 2015-03-02  719000.00         4       2.50         2570
# ...           ...        ...        ...       ...        ...          ...
# 21135  2025049203 2014-06-10  399950.00         2       1.00          710
# 21136   952006823 2014-12-02  380000.00         3       2.50         1260
# 21137  3832050760 2014-08-28  270000.00         3       2.50         1870
# 21138  2767604724 2014-10-15  505000.00         2       2.50         1430
# 21139  6632300207 2015-03-05  385000.00         3       2.50         1520
# 21140  2767600688 2014-11-13  414500.00         2       1.50         1210
# 21141  7570050450 2014-09-10  347500.00         3       2.50         2540
# 21142  7430200100 2014-05-14 1222500.00         4       3.50         4910
# 21143  4140940150 2014-10-02  572000.00         4       2.75         2770
# 21144  1931300412 2015-04-16  475000.00         3       2.25         1190
# 21145  8672200110 2015-03-17 1088000.00         5       3.75         4170
# 21146  5087900040 2014-10-17  350000.00         4       2.75         2500
# 21147  1972201967 2014-10-31  520000.00         2       2.25         1530
# 21148  7502800100 2014-08-13  679950.00         5       2.75         3600
# 21149   191100405 2015-04-21 1575000.00         4       3.25         3410
# 21150  8956200760 2014-10-13  541800.00         4       2.50         3118
# 21151  7202300110 2014-09-15  810000.00         4       3.00         3990
# 21152   249000205 2014-10-15 1537000.00         5       3.75         4470
# 21153  5100403806 2015-04-07  467000.00         3       2.50         1425
# 21154   844000965 2014-06-26  224000.00         3       1.75         1500
# 21155  7852140040 2014-08-25  507250.00         3       2.50         2270
# 21156  9834201367 2015-01-26  429000.00         3       2.00         1490
# 21157  3448900210 2014-10-14  610685.00         4       2.50         2520
# 21158  7936000429 2015-03-26 1007500.00         4       3.50         3510
# 21159  2997800021 2015-02-19  475000.00         3       2.50         1310
# 21160   263000018 2014-05-21  360000.00         3       2.50         1530
# 21161  6600060120 2015-02-23  400000.00         4       2.50         2310
# 21162  1523300141 2014-06-23  402101.00         2       0.75         1020
# 21163   291310100 2015-01-16  400000.00         3       2.50         1600
# 21164  1523300157 2014-10-15  325000.00         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view     ...       lat    long  \
# 0          5650    1.00           0     0     ...     47.51 -122.26
# 1          7242    2.00           0     0     ...     47.72 -122.32
# 2         10000    1.00           0     0     ...     47.74 -122.23
# 3          5000    1.00           0     0     ...     47.52 -122.39
# 4          8080    1.00           0     0     ...     47.62 -122.05
# 5        101930    1.00           0     0     ...     47.66 -122.00
# 6          6819    2.00           0     0     ...     47.31 -122.33
# 7          9711    1.00           0     0     ...     47.41 -122.31
# 8          7470    1.00           0     0     ...     47.51 -122.34
# 9          6560    2.00           0     0     ...     47.37 -122.03
# 10         9796    1.00           0     0     ...     47.60 -122.14
# 11         6000    1.00           0     0     ...     47.69 -122.29
# 12        19901    1.50           0     0     ...     47.76 -122.23
# 13         9680    1.00           0     0     ...     47.61 -122.05
# 14         4850    1.50           0     0     ...     47.67 -122.39
# 15         5000    2.00           0     3     ...     47.57 -122.38
# 16        14040    2.00           0     0     ...     47.73 -121.96
# 17         4300    1.50           0     0     ...     47.66 -122.34
# 18         9850    1.00           0     0     ...     47.31 -122.21
# 19         9774    1.00           0     0     ...     47.33 -122.31
# 20         4980    1.00           0     0     ...     47.70 -122.34
# 21        44867    1.00           0     4     ...     47.53 -122.23
# 22         6300    2.00           0     0     ...     47.33 -122.17
# 23         9643    1.00           0     0     ...     47.35 -122.17
# 24         6500    2.00           0     0     ...     47.37 -122.17
# 25         4697    1.50           0     0     ...     47.30 -122.22
# 26         2691    2.00           0     0     ...     47.64 -122.36
# 27         1581    1.50           0     0     ...     47.62 -122.31
# 28         6380    1.00           0     0     ...     47.70 -122.30
# 29         7173    2.00           0     0     ...     47.71 -122.11
# ...         ...     ...         ...   ...     ...       ...     ...
# 21135      1157    2.00           0     0     ...     47.64 -122.33
# 21136       900    2.00           0     0     ...     47.56 -122.38
# 21137      5000    2.00           0     0     ...     47.33 -122.06
# 21138      1201    3.00           0     0     ...     47.67 -122.38
# 21139      1488    3.00           0     0     ...     47.73 -122.31
# 21140      1278    2.00           0     0     ...     47.68 -122.38
# 21141      4760    2.00           0     0     ...     47.35 -122.02
# 21142      9444    1.50           0     0     ...     47.65 -122.07
# 21143      3852    2.00           0     0     ...     47.50 -122.23
# 21144      1200    3.00           0     0     ...     47.65 -122.35
# 21145      8142    2.00           0     2     ...     47.54 -122.18
# 21146      5995    2.00           0     0     ...     47.37 -122.11
# 21147       981    3.00           0     0     ...     47.65 -122.35
# 21148      9437    2.00           0     0     ...     47.48 -122.13
# 21149     10125    2.00           0     0     ...     47.57 -122.22
# 21150      7866    2.00           0     2     ...     47.29 -122.26
# 21151      7838    2.00           0     0     ...     47.69 -122.05
# 21152      8088    2.00           0     0     ...     47.63 -122.20
# 21153      1179    3.00           0     0     ...     47.70 -122.32
# 21154     11968    1.00           0     0     ...     47.31 -122.00
# 21155      5536    2.00           0     0     ...     47.54 -121.88
# 21156      1126    3.00           0     0     ...     47.57 -122.29
# 21157      6023    2.00           0     0     ...     47.51 -122.17
# 21158      7200    2.00           0     0     ...     47.55 -122.40
# 21159      1294    2.00           0     0     ...     47.58 -122.41
# 21160      1131    3.00           0     0     ...     47.70 -122.35
# 21161      5813    2.00           0     0     ...     47.51 -122.36
# 21162      1350    2.00           0     0     ...     47.59 -122.30
# 21163      2388    2.00           0     0     ...     47.53 -122.07
# 21164      1076    2.00           0     0     ...     47.59 -122.30
#
#        sqft_living15  sqft_lot15  walking_score  transit_score  bike_score  \
# 0               1340        5650             24          46.00       22.00
# 1               1690        7639             67          59.00       64.00
# 2               2720        8062             14          36.00         nan
# 3               1360        5000             74          48.00       51.00
# 4               1800        7503              9           0.00         nan
# 5               4760      101930             16           0.00         nan
# 6               2238        6819             65          45.00         nan
# 7               1650        9711             22            nan         nan
# 8               1780        8113             39          40.00         nan
# 9               2390        7570              2            nan         nan
# 10              2210        8925             61          43.00       54.00
# 11              1330        6000             61          52.00       72.00
# 12              1780       12697             14          36.00         nan
# 13              1370       10208              9           0.00         nan
# 14              1360        4850             96          55.00       80.00
# 15              2140        4000             54          51.00       48.00
# 16              1890       14018              0            nan         nan
# 17              1610        4300             89          62.00       82.00
# 18              1060        5095             73          36.00         nan
# 19              1280        8850             65          45.00         nan
# 20              1400        4980             80          52.00         nan
# 21              4110       20336             71          40.00         nan
# 22              2240        7005              0           0.00         nan
# 23              1220        8386             63          37.00         nan
# 24              2200        6865             63          37.00         nan
# 25              1030        4705             73          36.00         nan
# 26              1760        3573             85          61.00       56.00
# 27              1860        3861             52          42.00       61.00
# 28              1520        6235             61          52.00       72.00
# 29              2630        6026             81          49.00         nan
# ...              ...         ...            ...            ...         ...
# 21135           1370        1173             73          60.00       52.00
# 21136           1310        1415             56          35.00       26.00
# 21137           2170        5399             36            nan         nan
# 21138           1430        1249             96          55.00       80.00
# 21139           1520        1497             67          59.00       64.00
# 21140           1210        1118             83          52.00       70.00
# 21141           2540        4571              2            nan         nan
# 21142           4560       11063              9           0.00         nan
# 21143           1810        5641             24          46.00       22.00
# 21144           1180        1224             89          62.00       82.00
# 21145           3030        7980             12          26.00         nan
# 21146           2530        5988             36            nan         nan
# 21147           1530        1282             89          62.00       82.00
# 21148           3550        9421             27          15.00         nan
# 21149           2290       10125             71          40.00         nan
# 21150           2673        6500             13          22.00         nan
# 21151           3370        6814             16           0.00         nan
# 21152           2780        8964             56          46.00       37.00
# 21153           1285        1253             67          59.00       64.00
# 21154           1320       11303             34            nan         nan
# 21155           2270        5731              0            nan         nan
# 21156           1400        1230             85          75.00       79.00
# 21157           2520        6023             12          26.00         nan
# 21158           2050        6200             74          48.00       51.00
# 21159           1330        1265             56          35.00       26.00
# 21160           1530        1509             89          62.00       82.00
# 21161           1830        7200             39          40.00         nan
# 21162           1020        2007             85          75.00       79.00
# 21163           1410        1287              0           0.00         nan
# 21164           1020        1357             85          75.00       79.00
#
#        median_income  mean_income  population
# 0           55777.00     65498.00       24092
# 1           47910.00     60487.00       30826
# 2           86310.00    100546.00       20419
# 3           77761.00     95355.00       14770
# 4          134159.00    157543.00       25748
# 5          114287.00    149341.00       18784
# 6           52410.00     63083.00       44151
# 7           59070.00     69813.00       34584
# 8           53913.00     69002.00       25922
# 9           94082.00    104078.00       31171
# 10          69589.00     84662.00       24889
# 11          82556.00    106972.00       46206
# 12          86310.00    100546.00       20419
# 13         134159.00    157543.00       25748
# 14          64804.00     79532.00       21147
# 15          64247.00     77711.00       20698
# 16          99893.00    106938.00       10725
# 17          69942.00     85947.00       45911
# 18          40586.00     49092.00       31647
# 19          52410.00     63083.00       44151
# 20          57182.00     71395.00       44555
# 21         128906.00    187222.00       22699
# 22          77882.00     88699.00       39816
# 23          56657.00     68952.00       33769
# 24          56657.00     68952.00       33769
# 25          40586.00     49092.00       31647
# 26          67705.00     99361.00       21039
# 27          90529.00    137945.00       21077
# 28          82556.00    106972.00       46206
# 29          93173.00    111386.00       58442
# ...              ...          ...         ...
# 21135       57724.00     85545.00       20756
# 21136       75728.00    101537.00       22241
# 21137       82732.00     94033.00       43673
# 21138       64804.00     79532.00       21147
# 21139       47910.00     60487.00       30826
# 21140       76908.00     90008.00       31365
# 21141       94082.00    104078.00       31171
# 21142      134159.00    157543.00       25748
# 21143       55777.00     65498.00       24092
# 21144       69942.00     85947.00       45911
# 21145       64105.00     76264.00       32489
# 21146       82732.00     94033.00       43673
# 21147       69942.00     85947.00       45911
# 21148       84573.00    101223.00       34463
# 21149      128906.00    187222.00       22699
# 21150       73052.00     82554.00       31911
# 21151      114287.00    149341.00       18784
# 21152       99669.00    144248.00       27946
# 21153       47910.00     60487.00       30826
# 21154       87030.00     95747.00        5025
# 21155      108108.00    127022.00       12699
# 21156       58263.00     80542.00       26881
# 21157       64105.00     76264.00       32489
# 21158       77761.00     95355.00       14770
# 21159       75728.00    101537.00       22241
# 21160       69942.00     85947.00       45911
# 21161       53913.00     69002.00       25922
# 21162       58263.00     80542.00       26881
# 21163       94297.00    119651.00       26141
# 21164       58263.00     80542.00       26881
#
# [21165 rows x 27 columns]

# %% [markdown]
# ## Data Perspective
# - One variable
#     - Numeric variables
#         - continuous: average income
#         - discrete: population
#     - Categorical variables
#         - ordinal: grade
#         - nominal: house, apartment, townhouse, etc.
# - Multiple variables
#     - Numeric x Numeric
#     - Categorical x Numeric
#     - Categorical x Categorical

# %% [markdown]
# ## One Variable (numeric)

# %%
# Analize pricing distribution

# Histogram
print(df['price'].describe().round())
plt.hist(df['price'], bins=100)
plt.show()
# Box plot
plt.boxplot(df['price'])
plt.xticks([1], ['Price'], rotation='horizontal')
plt.show()
# Out:
# count     21165.00
# mean     518266.00
# std      304494.00
# min       75000.00
# 25%      320000.00
# 50%      446950.00
# 75%      629950.00
# max     5570000.00
# Name: price, dtype: float64

# %% [markdown]
# ## One Variable (categorical)

# %%
# Analize zipcode distribution
print(df['bedrooms'].value_counts())

# Bar Chart
plt.figure(figsize=(12,6))
plt.title('# houses by bedroom')
plt.xlabel('bedrooms')
plt.ylabel('# houses')

labels = df['bedrooms'].value_counts().index
values = df['bedrooms'].value_counts().values

y_pos = range(len(labels))
plt.bar(y_pos, values, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.show()
# Out:
# 3    9742
# 4    6703
# 2    2747
# 5    1521
# 6     253
# 1     199
# Name: bedrooms, dtype: int64

# %% [markdown]
# ## Multiple variables (Numeric x Numeric)

# %%
# Correlation
df.corr()
# Out:
#                  id  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.00  -0.01      0.01       0.01        -0.01     -0.13
# price         -0.01   1.00      0.32       0.50         0.68      0.07
# bedrooms       0.01   0.32      1.00       0.52         0.60      0.03
# bathrooms      0.01   0.50      0.52       1.00         0.74      0.07
# sqft_living   -0.01   0.68      0.60       0.74         1.00      0.16
# sqft_lot      -0.13   0.07      0.03       0.07         0.16      1.00
# floors         0.02   0.26      0.17       0.51         0.35     -0.02
# waterfront    -0.00   0.09     -0.03       0.00         0.01      0.02
# view           0.02   0.31      0.06       0.14         0.23      0.06
# condition     -0.02   0.04      0.02      -0.13        -0.06     -0.01
# grade          0.02   0.67      0.37       0.65         0.75      0.09
# sqft_above    -0.00   0.58      0.49       0.67         0.87      0.16
# sqft_basement -0.00   0.29      0.30       0.25         0.41      0.01
# yr_built       0.03   0.06      0.17       0.53         0.33      0.05
# yr_renovated  -0.02   0.11      0.01       0.04         0.04      0.01
# zipcode       -0.01  -0.06     -0.17      -0.22        -0.22     -0.13
# lat           -0.00   0.35     -0.02       0.02         0.05     -0.08
# long           0.02   0.03      0.15       0.24         0.26      0.23
# sqft_living15 -0.00   0.59      0.41       0.56         0.76      0.15
# sqft_lot15    -0.14   0.07      0.03       0.07         0.17      0.71
# walking_score  0.00   0.10     -0.12      -0.14        -0.19     -0.21
# transit_score -0.01   0.06     -0.14      -0.18        -0.23     -0.26
# bike_score     0.03  -0.07     -0.17      -0.10        -0.22     -0.37
# median_income  0.01   0.43      0.17       0.32         0.39      0.13
# mean_income    0.01   0.56      0.17       0.31         0.40      0.10
# population     0.03  -0.15      0.02      -0.06        -0.10     -0.15
#
#                floors  waterfront  view  condition     ...       lat  long  \
# id               0.02       -0.00  0.02      -0.02     ...     -0.00  0.02
# price            0.26        0.09  0.31       0.04     ...      0.35  0.03
# bedrooms         0.17       -0.03  0.06       0.02     ...     -0.02  0.15
# bathrooms        0.51        0.00  0.14      -0.13     ...      0.02  0.24
# sqft_living      0.35        0.01  0.23      -0.06     ...      0.05  0.26
# sqft_lot        -0.02        0.02  0.06      -0.01     ...     -0.08  0.23
# floors           1.00        0.00  0.00      -0.27     ...      0.05  0.13
# waterfront       0.00        1.00  0.29       0.02     ...     -0.03 -0.05
# view             0.00        0.29  1.00       0.05     ...     -0.00 -0.08
# condition       -0.27        0.02  0.05       1.00     ...     -0.02 -0.10
# grade            0.46        0.01  0.20      -0.15     ...      0.12  0.21
# sqft_above       0.53        0.01  0.11      -0.16     ...     -0.00  0.36
# sqft_basement   -0.27        0.02  0.24       0.18     ...      0.11 -0.15
# yr_built         0.50       -0.04 -0.06      -0.36     ...     -0.15  0.41
# yr_renovated     0.00        0.07  0.08      -0.06     ...      0.03 -0.06
# zipcode         -0.06        0.02  0.08       0.00     ...      0.27 -0.56
# lat              0.05       -0.03 -0.00      -0.02     ...      1.00 -0.13
# long             0.13       -0.05 -0.08      -0.10     ...     -0.13  1.00
# sqft_living15    0.27        0.03  0.25      -0.10     ...      0.05  0.34
# sqft_lot15      -0.02        0.03  0.06       0.00     ...     -0.08  0.25
# walking_score    0.01       -0.03 -0.01       0.07     ...      0.30 -0.59
# transit_score   -0.01       -0.02  0.02       0.04     ...      0.38 -0.63
# bike_score       0.20       -0.05 -0.12      -0.05     ...      0.60 -0.48
# median_income    0.17        0.01  0.03      -0.06     ...      0.22  0.57
# mean_income      0.16        0.02  0.06      -0.03     ...      0.29  0.44
# population      -0.04       -0.05 -0.10       0.05     ...     -0.07 -0.21
#
#                sqft_living15  sqft_lot15  walking_score  transit_score  \
# id                     -0.00       -0.14           0.00          -0.01
# price                   0.59        0.07           0.10           0.06
# bedrooms                0.41        0.03          -0.12          -0.14
# bathrooms               0.56        0.07          -0.14          -0.18
# sqft_living             0.76        0.17          -0.19          -0.23
# sqft_lot                0.15        0.71          -0.21          -0.26
# floors                  0.27       -0.02           0.01          -0.01
# waterfront              0.03        0.03          -0.03          -0.02
# view                    0.25        0.06          -0.01           0.02
# condition              -0.10        0.00           0.07           0.04
# grade                   0.70        0.10          -0.11          -0.19
# sqft_above              0.73        0.18          -0.26          -0.30
# sqft_basement           0.18        0.01           0.09           0.08
# yr_built                0.33        0.06          -0.32          -0.35
# yr_renovated           -0.01        0.01           0.05           0.06
# zipcode                -0.29       -0.15           0.27           0.37
# lat                     0.05       -0.08           0.30           0.38
# long                    0.34        0.25          -0.59          -0.63
# sqft_living15           1.00        0.18          -0.26          -0.31
# sqft_lot15              0.18        1.00          -0.23          -0.30
# walking_score          -0.26       -0.23           1.00           0.85
# transit_score          -0.31       -0.30           0.85           1.00
# bike_score             -0.30       -0.38           0.85           0.75
# median_income           0.49        0.15          -0.43          -0.52
# mean_income             0.48        0.12          -0.30          -0.40
# population             -0.10       -0.17           0.33           0.12
#
#                bike_score  median_income  mean_income  population
# id                   0.03           0.01         0.01        0.03
# price               -0.07           0.43         0.56       -0.15
# bedrooms            -0.17           0.17         0.17        0.02
# bathrooms           -0.10           0.32         0.31       -0.06
# sqft_living         -0.22           0.39         0.40       -0.10
# sqft_lot            -0.37           0.13         0.10       -0.15
# floors               0.20           0.17         0.16       -0.04
# waterfront          -0.05           0.01         0.02       -0.05
# view                -0.12           0.03         0.06       -0.10
# condition           -0.05          -0.06        -0.03        0.05
# grade               -0.13           0.41         0.43       -0.07
# sqft_above          -0.19           0.43         0.41       -0.11
# sqft_basement       -0.12          -0.01         0.05       -0.00
# yr_built            -0.14           0.30         0.21       -0.02
# yr_renovated         0.03          -0.01         0.03       -0.04
# zipcode              0.36          -0.36        -0.28       -0.07
# lat                  0.60           0.22         0.29       -0.07
# long                -0.48           0.57         0.44       -0.21
# sqft_living15       -0.30           0.49         0.48       -0.10
# sqft_lot15          -0.38           0.15         0.12       -0.17
# walking_score        0.85          -0.43        -0.30        0.33
# transit_score        0.75          -0.52        -0.40        0.12
# bike_score           1.00          -0.30        -0.27        0.30
# median_income       -0.30           1.00         0.95       -0.26
# mean_income         -0.27           0.95         1.00       -0.29
# population           0.30          -0.26        -0.29        1.00
#
# [26 rows x 26 columns]

# %%
# heatmap
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()

# %%
# Visualization : correlation between Price x SQFT

plt.figure(figsize=(10,10))
plt.xlabel('Price')
plt.ylabel('SQFT')

plt.plot(df['price'], df['sqft_living'], 'o', alpha=0.3)
plt.show()

# %%
# TODO: Create a scatterplot Price x Mean Income
# TODO: What is the correlation between Price x Mean Income

print('Correlation:', df[['price', 'mean_income']].corr())

plt.figure(figsize=(10,10))
plt.xlabel('Price')
plt.ylabel('Income')

plt.plot(df['price'], df['mean_income'], 'o', alpha=0.3)
plt.show()
# Out:
# ('Correlation:',              price  mean_income
# price         1.00         0.56
# mean_income   0.56         1.00)

# %% [markdown]
# ## Multiple variables (Categorical x Numeric)

# %%
# Box plot to show the distribution between bedrooms x price
values = []
labels = []
for bdr in sorted(df['bedrooms'].unique()):
    labels.append(bdr)
    values.append(list(df[df['bedrooms']==bdr]['price'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %% [markdown]
# ## Multiple variables (Categorical x Categorical)

# %%
# Count of number of houses by zipcode and bedrooms

n_bedrooms = [2,3,4]
zipcodes = df['zipcode'].unique()
r = range(len(zipcodes))

df_group = df.groupby(['zipcode', 'bedrooms'])['id'].count().reset_index()
df_group = df.pivot_table(index='zipcode', columns = 'bedrooms', values='id')
df_group = df_group[[2,3,4]]
df_group.columns = ['2BR','3BR','4BR']
df_group = df_group.sort_values(['2BR','3BR','4BR'])

raw_data = {'2BR': df_group['2BR'].values, 
            '3BR': df_group['3BR'].values, 
            '4BR': df_group['4BR'].values
           }

# From raw value to percentage
totals = [float(i+j+k) for i,j,k in zip(raw_data['2BR'], raw_data['3BR'], raw_data['4BR'])]
br2Bars = [i / j * 100 for i,j in zip(raw_data['2BR'], totals)]
br3Bars = [i / j * 100 for i,j in zip(raw_data['3BR'], totals)]
br4Bars = [i / j * 100 for i,j in zip(raw_data['4BR'], totals)]

# plot
barWidth = 0.85
names = zipcodes
plt.figure(figsize=(12,6))
# Create green Bars
plt.bar(r, br2Bars, edgecolor='white', width=barWidth, alpha=0.7, color='g', label='2BR')
# Create orange Bars
plt.bar(r, br3Bars, bottom=br2Bars, edgecolor='white', width=barWidth, alpha=0.7, color='orange', label='3BR')
# Create blue Bars
plt.bar(r, br4Bars, bottom=[i+j for i,j in zip(br2Bars, br3Bars)], edgecolor='white', width=barWidth, alpha=0.7, color='b', label='4BR')

# Limit on y-axis
plt.ylim(0,100)

# Custom x axis
plt.xticks(r, names, rotation='vertical')
plt.ylabel("Percent")
plt.xlabel("zipcode")

plt.legend()

# Show graphic
plt.show()

# %% [markdown]
# ## Business Perspective
# "An approximate answer to the right question is worth a great deal more than a precise answer to the wrong question." John Tukey

# %%
# What is the total number of sales per month?

df_group = df.groupby([df['date'].dt.to_period('M')])['price'].count()

# chart
df_group.index = df_group.index.to_timestamp()
plt.title('Total number of sales per month')
plt.xlabel('Month')
plt.ylabel('# sales')
plt.plot(df_group.index, df_group.values, '-')
plt.show()

# table
df_group
# Out:
# date
# 2014-05-01    1737
# 2014-06-01    2136
# 2014-07-01    2172
# 2014-08-01    1903
# 2014-09-01    1732
# 2014-10-01    1835
# 2014-11-01    1380
# 2014-12-01    1438
# 2015-01-01     955
# 2015-02-01    1225
# 2015-03-01    1841
# 2015-04-01    2182
# 2015-05-01     629
# Freq: MS, Name: price, dtype: int64

# %%
# What is the total sales ($) per month?

df_group = df.groupby([df['date'].dt.to_period('M')])['price'].sum()

# chart
df_group.index = df_group.index.to_timestamp()
plt.title('Total Sales ($) per month')
plt.xlabel('Month')
plt.ylabel('$')
plt.plot(df_group.index, df_group.values, '-')
plt.show()

# table
df_group
# Out:
# date
# 2014-05-01    924249090.00
# 2014-06-01   1139387745.00
# 2014-07-01   1149641358.00
# 2014-08-01    980751787.00
# 2014-09-01    869951373.00
# 2014-10-01    946989353.00
# 2014-11-01    685052934.00
# 2014-12-01    719537956.00
# 2015-01-01    479770830.00
# 2015-02-01    605830774.00
# 2015-03-01    969413826.00
# 2015-04-01   1172895973.00
# 2015-05-01    325626530.00
# Freq: MS, Name: price, dtype: float64

# %%
# What is the total number of sales per day of week?

df_group = df.groupby([df['date'].dt.dayofweek])['price'].count()

# chart
plt.title('Total number of sales per day of week')
plt.xlabel('Day of Week')
plt.ylabel('Sales')
values = df_group.values
bars = [str(x) for x in df_group.index]
y_pos = np.arange(len(bars))
plt.bar(y_pos, values, align='center')
plt.xticks(y_pos, bars)
plt.show()

df_group
# Out:
# date
# 0    4021
# 1    4620
# 2    4491
# 3    3922
# 4    3601
# 5     282
# 6     228
# Name: price, dtype: int64

# %%
# What is the average price by zip code?
df.groupby(by=['zipcode'])['price'].mean().sort_values()
# Out:
# zipcode
# 98002    234284.04
# 98168    238008.92
# 98032    248927.66
# 98148    273986.18
# 98001    276637.11
# 98023    279993.23
# 98188    280472.59
# 98198    283963.56
# 98003    284387.44
# 98178    293929.85
# 98031    294436.17
# 98030    295133.82
# 98055    301619.79
# 98042    303617.21
# 98022    304324.46
# 98106    312284.61
# 98092    322294.41
# 98146    338273.75
# 98058    342938.88
# 98108    355678.52
# 98038    357789.46
# 98133    380018.53
# 98155    401461.64
# 98118    402807.25
# 98056    407292.45
# 98019    415830.81
# 98126    416833.95
# 98010    423665.99
# 98045    424817.01
# 98014    426500.18
#            ...
# 98072    557694.32
# 98107    561628.17
# 98117    563718.08
# 98024    569856.58
# 98103    570616.92
# 98027    588274.21
# 98008    592259.38
# 98029    592727.97
# 98007    598183.83
# 98116    599908.60
# 98122    599933.52
# 98115    603853.69
# 98177    627364.56
# 98052    633543.23
# 98053    655456.90
# 98074    661827.13
# 98077    665689.36
# 98033    755747.93
# 98199    757828.05
# 98075    766801.75
# 98005    778335.58
# 98119    784290.59
# 98105    807180.45
# 98006    816550.56
# 98102    835516.02
# 98109    839055.84
# 98112   1048445.68
# 98040   1133284.55
# 98004   1292952.55
# 98039   2056152.71
# Name: price, dtype: float64

# %%
# Identify the zip codes with highest and lowest price per square foot
df['price_x_sqft_living'] = df['price']/df['sqft_living']
df.groupby(by=['zipcode'])['price_x_sqft_living'].mean().sort_values()
# Out:
# zipcode
# 98023   147.52
# 98001   151.08
# 98002   151.17
# 98032   154.66
# 98092   154.90
# 98030   155.06
# 98003   156.73
# 98031   159.98
# 98042   163.80
# 98188   168.69
# 98038   172.62
# 98168   175.54
# 98198   175.62
# 98058   177.05
# 98022   178.57
# 98055   180.47
# 98178   183.52
# 98148   186.01
# 98019   202.93
# 98059   205.69
# 98065   210.09
# 98010   210.10
# 98056   212.85
# 98146   219.46
# 98045   220.07
# 98166   221.88
# 98014   221.92
# 98028   223.83
# 98108   224.44
# 98011   225.61
#          ...
# 98075   264.13
# 98053   268.95
# 98029   270.93
# 98070   275.25
# 98125   277.88
# 98052   278.21
# 98177   287.93
# 98007   289.95
# 98126   292.06
# 98006   294.29
# 98008   295.23
# 98144   307.20
# 98005   311.69
# 98136   334.17
# 98033   338.65
# 98116   347.05
# 98115   353.01
# 98117   363.17
# 98122   363.66
# 98103   369.48
# 98199   373.06
# 98107   381.72
# 98040   382.77
# 98105   403.10
# 98119   425.12
# 98102   426.01
# 98109   430.77
# 98112   435.72
# 98004   473.34
# 98039   566.32
# Name: price_x_sqft_living, dtype: float64

# %%
# Is the grade a good indicator of price?

# Analysis
print('Correlation:', df[['price', 'grade']].corr())

# Chart
plt.figure(figsize=(10,10))
plt.xlabel('Price')
plt.ylabel('Grade')
plt.plot(df['price'], df['grade'], 'o', alpha=0.3)
plt.show()
# Out:
# ('Correlation:',        price  grade
# price   1.00   0.67
# grade   0.67   1.00)

# %%
# Is the walking score a good indicator of price?

# Analysis
print('Correlation:', df[['price', 'walking_score']].corr())

# Chart
plt.figure(figsize=(10,10))
plt.xlabel('Price')
plt.ylabel('Walking Score')
plt.plot(df['price'], df['walking_score'], 'o', alpha=0.3)
plt.show()
# Out:
# ('Correlation:',                price  walking_score
# price           1.00           0.10
# walking_score   0.10           1.00)

# %%
df_zip = df.groupby('zipcode')[['price', 'walking_score']].mean()
plt.plot(df_zip['price'], df_zip['walking_score'], 'o')
plt.show()
